# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris

# %%
#data=pd.read_csv('Dataset/Internal/ConsolidateOutput.csv')
data = pd.read_csv('internal50.csv')
data.head()
# Out:
#    NO.  ma_internals  ph100_internals  be10105_internals  be110_internals  \
# 0    1            25               23                 35               48
# 1    2            41               46                 47               46
# 2    3            47               50                 47               37
# 3    5            31               41                 42               39
# 4    6            45               46                 40               41
#
#    be103_internals  ec100_internals  ph110_internals  ec110_internals  \
# 0               36               30               43               42
# 1               40               37               48               43
# 2               46               50               48               43
# 3               42               43               47               48
# 4               41               39               46               47
#
#    cs110_internals  ...  HS300_internals  CS304_internals  IT304_internals  \
# ...

# %%
x=data
xtrain, xtest = train_test_split(x, test_size = 0.2, random_state = 0)

# %%
xtrain.shape
# Out:
# (43, 47)

# %%
xtest.shape
# Out:
# (11, 47)

# %%
xtest
# Out:
#     NO.  ma_internals  ph100_internals  be10105_internals  be110_internals  \
# 53   62            27               25                 38               40
# 33   40            38               42                 41               39
# 48   57            45               46                 42               47
# 26   33            45               39                 47               46
# 11   13            33               42                 46               41
# 2     3            47               50                 47               37
# 32   39            45               43                 42               47
# 42   51            26               29                 38               39
# 45   54            39               43                 43               42
# 30   37            45               50                 48               42
# 4     6            45               46                 40               41
#
# ...

# %%
xtrain
# Out:
#     NO.  ma_internals  ph100_internals  be10105_internals  be110_internals  \
# 10   12            36               39                 35               42
# 28   35            32               34                 38               33
# 22   26            48               43                 46               42
# 31   38            37               50                 45               34
# 38   45            46               39                 46               42
# 37   44            46               47                 45               41
# 7     9            31               34                 35               34
# 14   17            46               46                 50               46
# 27   34            23               27                 38               36
# 35   42            46               45                 43               39
# 49   58            33               36                 36               44
# ...

# %%
xtrain.to_csv (r'all_train_int50.csv', index = False, header=True)
xtest.to_csv (r'all_test_int50.csv', index = False, header=True)
