# %%
import pandas as pd

# %%
df = pd.read_excel('/home/vaisakh/new/S07.xls',header = 1)

# %%
df
# Out:
#     Unnamed: 0                                Student IT401 IT403 IT405 IT407  \
# 0          NaN          IDK15IT031-KRISHNA PRIYA M S      B     B     B     C
# 1          NaN                   IDK15IT045-NEETHU  K     F     F     F     F
# 2          NaN               IDK16IT001-ABHINANDHA  P     F     B     B     C
# 3          NaN              IDK16IT002-AHMED BAHEEJ K     B    B+    A+     B
# 4          NaN               IDK16IT003-AISWARYA  K.P     B    A+    B+    B+
# 5          NaN                     IDK16IT004-AJMAL       C    B+     B     C
# 6          NaN                IDK16IT006-AKHIL  VINOD    FE    AB     P    AB
# 7          NaN                  IDK16IT007-ANANTHU  K     F     B     C     F
# 8          NaN                 IDK16IT008-ANJALI  K P    B+     O     O    B+
# 9          NaN               IDK16IT010-ANWAR  FAROOQ     C    B+     B     B
# 10         NaN                     IDK16IT011-ARUN  G     F    B+    B+     C
# ...

# %%
df.drop(df.columns[df.columns.str.contains('unnamed', case=False)],
          axis=1, inplace=True)
df=df.drop(index=[0,1] ,axis=1)

# %%
#df = df.drop(columns = ['MAT101','CYT100','EST100','EST130','HUN101','CYL120','ESL130','Earned Credits','Cumilative Credits','SGPA','CGPA'])
#df = df.drop(columns = ['MAT102','PHT100','EST110','EST120','HUN102','EST102','PHL120','ESL120','EE100','EE110','Earned Credits','Cumilative Credits','SGPA','CGPA'])
#df = df.drop(columns = ['Earned Credits','Cumilative Credits','SGPA','CGPA'])
#df = df.drop(columns = ['IT364','Earned Credits','Cumilative Credits','SGPA','CGPA'])
df = df.drop(columns = ['IT463','Earned Credits','Cumilative Credits','SGPA','CGPA'])

# %%
df
# Out:
#                                   Student IT401 IT403 IT405 IT407 IT409 IT465  \
# 2                IDK16IT001-ABHINANDHA  P     F     B     B     C     F     C
# 3               IDK16IT002-AHMED BAHEEJ K     B    B+    A+     B     B    B+
# 4                IDK16IT003-AISWARYA  K.P     B    A+    B+    B+    B+     C
# 5                      IDK16IT004-AJMAL       C    B+     B     C     C     F
# 6                 IDK16IT006-AKHIL  VINOD    FE    AB     P    AB    AB    AB
# 7                   IDK16IT007-ANANTHU  K     F     B     C     F     F     B
# 8                  IDK16IT008-ANJALI  K P    B+     O     O    B+    A+     B
# 9                IDK16IT010-ANWAR  FAROOQ     C    B+     B     B     B   NaN
# 10                     IDK16IT011-ARUN  G     F    B+    B+     C     C     B
# 11                  IDK16IT012-ASHETHA  K     B    A+     O     A     A   NaN
# 12                 IDK16IT013-ASHRITH  MV    AB     B    AB     F    AB     F
# ...

# %%
df.to_csv (r'idkgrade.csv', index = False, header=True)
