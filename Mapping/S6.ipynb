# %%
import pandas as pd
result=pd.read_csv('Downloads/s6.csv')

# %%
def nominalToNumber(dataframe,column,mapping):
    dataframe[column] = dataframe[column].map(mapping)
    return dataframe

def encodeData(studentData):
    registerno={
'TRV16IT001':1,
'TRV16IT002':2,
'TRV16IT003':3,
'TRV16IT005':5,
'TRV16IT006':6,
'TRV16IT007':7,
'TRV16IT008':8,
'TRV16IT009':9,
'TRV16IT010':10,
'TRV16IT011':11,
'TRV16IT012':12,
'TRV16IT013':13,
'TRV16IT015':15,
'TRV16IT016':16,
'TRV16IT017':17,
'TRV16IT018':18,
'TRV16IT019':19,
'TRV16IT020':20,
'TRV16IT021':21,
'TRV16IT022':22,
'TRV16IT023':23,
'TRV16IT024':24,
'TRV16IT025':25,
'TRV16IT026':26,
'TRV16IT028':28,
'TRV16IT030':30,
'TRV16IT031':31,
'TRV16IT032':32,
'TRV16IT033':33,
'TRV16IT034':34,
'TRV16IT035':35,
'TRV16IT036':36,
'TRV16IT037':37,
'TRV16IT038':38,
'TRV16IT039':39,
'TRV16IT040':40,
'TRV16IT041':41,
'TRV16IT042':42,
'TRV16IT043':43,
'TRV16IT044':44,
'TRV16IT045':45,
'TRV16IT046':46,
'TRV16IT048':48,
'TRV16IT049':49,
'TRV16IT050':50,
'TRV16IT051':51,
'TRV16IT052':52,
'TRV16IT053':53,
'TRV16IT054':54,
'TRV16IT055':55,
'TRV16IT056':56,
'TRV16IT057':57,
'TRV16IT058':58,
'TRV16IT059':59,
'TRV16IT060':60,
'TRV16IT061':61,
'TRV16IT062':62
}
    studentData = nominalToNumber(studentData,'NO.',registerno)
    
    gradeMapping = {'O':10,'A+':9,'A':8,'B+':7,'B':6,'C':5,'P':4,'F':0,'FE':0,'I':0}
    studentData = nominalToNumber(studentData,'HS300',gradeMapping)
    studentData = nominalToNumber(studentData,'CS304',gradeMapping)
    studentData = nominalToNumber(studentData,'IT304',gradeMapping)
    studentData = nominalToNumber(studentData,'IT306',gradeMapping)
    studentData = nominalToNumber(studentData,'IT364',gradeMapping)
    studentData = nominalToNumber(studentData,'IT302',gradeMapping)
    studentData = nominalToNumber(studentData,'IT332',gradeMapping)
    studentData = nominalToNumber(studentData,'IT334',gradeMapping)
    studentData = nominalToNumber(studentData,'IT352',gradeMapping)
    studentData = nominalToNumber(studentData,'IT366',gradeMapping)
    
    return studentData

# %%
encodeData(result)
# Out:
#     NO.  HS300_internals  HS300  CS304_internals  CS304  IT304_internals  \
# 0     1               31      5               29    0.0               26
# 1     2               42      7               41    6.0               36
# 2     3               46      8               50    9.0               46
# 3     5               46      7               46    9.0               48
# 4     6               42      7               45    7.0               42
# 5     7               43      7               42    9.0               45
# 6     8               45      7               32    5.0               39
# 7     9               37      6               36    6.0               34
# 8    10               34      6               32    0.0               36
# 9    11               48      9               46    8.0               49
# 10   12               34      6               31    5.0               27
# 11   13               42      7               29    6.0               28
# 12   15               43      7               44    7.0               45
# 13   16               43      8               44    6.0               43
# 14   17               46      7               41    7.0               47
# 15   19               43      7               41    8.0               49
# 16   20               38      7               44    8.0               47
# 17   21               44      7               35    0.0               41
# 18   22               41      7               46    7.0               45
# 19   23               44      7               45    7.0               44
# 20   24               41      7               49    6.0               49
# 21   25               42      7               47    5.0               42
# 22   26               50      8               48    8.0               49
# 23   28               24      4               31    NaN               24
# 24   30               42      7               42    7.0               39
# 25   31               42      7               37    7.0               35
# 26   33               46      7               39    7.0               45
# 27   34               36      7               42    7.0               38
# 28   35               41      6               45    7.0               44
# 29   36               35      6               37    6.0               38
# 30   37               43      7               48    8.0               48
# 31   38               39      6               42    7.0               44
# 32   39               36      6               36    5.0               42
# 33   40               39      7               40    0.0               36
# 34   41               32      5               25    0.0               26
# 35   42               46      8               47    9.0               43
# 36   43               46      7               44    7.0               46
# 37   44               44      7               39    7.0               45
# 38   45               40      5               38    6.0               34
# 39   46               41      7               37    5.0               42
# 40   48               29      6               25    5.0               26
# 41   49               37      6               31    5.0               43
# 42   51               28      0               23    NaN               24
# 43   52               45      8               43    6.0               47
# 44   53               41      7               46    7.0               40
# 45   54               42      7               45    8.0               45
# 46   55               39      6               40    6.0               45
# 47   56               32      5               32    7.0               39
# 48   57               47      9               46   10.0               50
# 49   58               42      5               45    7.0               35
# 50   59               39      6               40    6.0               40
# 51   60               31      0               26    0.0               28
# 52   61               29      0               30    5.0               26
# 53   62               29      0               34    5.0               27
#
#     IT304  IT306_internals  IT306 IT364_internals  ...  IT302_internals  \
# 0       4               31      5              25  ...               28
# 1       0               29      7               -  ...               41
# 2       7               46      9               -  ...               50
# 3       7               48     10              48  ...               48
# 4       6               38      7              39  ...               46
# 5       6               40      9               -  ...               45
# 6       6               41      8              33  ...               35
# 7       5               45      8               -  ...               39
# 8       6               31      7               -  ...               32
# 9       7               47     10              48  ...               49
# 10      0               32      5              28  ...               35
# 11      7               33      7               -  ...               37
# 12      9               41      8               -  ...               50
# 13      8               43      9               -  ...               49
# 14      8               46     10               -  ...               50
# 15      7               42      8              43  ...               44
# 16      7               43      8               -  ...               43
# 17      0               39      7              34  ...               37
# 18      7               37      9               -  ...               48
# 19      6               41      9              43  ...               44
# 20      6               32      6              36  ...               46
# 21      7               38      7               -  ...               46
# 22      9               48     10              50  ...               50
# 23      0               32      0              23  ...               29
# 24      6               38      7              41  ...               48
# 25      5               38      6              45  ...               44
# 26      7               36      8              39  ...               43
# 27      6               45      8               -  ...               45
# 28      8               43      9               -  ...               43
# 29      5               38      0               -  ...               37
# 30      9               48     10               -  ...               48
# 31      7               48      9              44  ...               37
# 32      6               40      6               -  ...               40
# 33      6               35      6               -  ...               38
# 34      0               33      5              26  ...               25
# 35      9               50     10               -  ...               50
# 36      9               43      8              43  ...               43
# 37      7               47      9              46  ...               43
# 38      5               41      7              35  ...               31
# 39      6               46      7              29  ...               29
# 40      6               26      7              24  ...               26
# 41      0               41      7              26  ...               32
# 42      0               25      5              23  ...               25
# 43      8               45      9              44  ...               50
# 44      7               38      7               -  ...               48
# 45      7               39      7              36  ...               30
# 46      7               41      7               -  ...               43
# 47      6               39      7              31  ...               43
# 48      9               49     10              49  ...               46
# 49      0               49      9               -  ...               37
# 50      6               32      7               -  ...               44
# 51      0               32      6              28  ...               39
# 52      0               31      5               -  ...               28
# 53      5               39      6              24  ...               36
#
#     IT302  IT332_internals  IT332  IT334_internals  IT334  IT352_internals  \
# 0       5               73      7               88      9               29
# 1       6               65      6               86      9               35
# 2       9               99     10               96     10               44
# 3       6               86      9               96     10               38
# 4       7               80      8               92     10               38
# 5       7               94     10               89      9               41
# 6       0               65      6               84      8               37
# 7       5               68      6               82      8               35
# 8       6               80      8               92     10               34
# 9       8               88      9               84      8               40
# 10      0               66      6               80      8               42
# 11      0               89      9               92     10               37
# 12      5               97     10               89      9               37
# 13      7               99     10               95     10               44
# 14      7               99     10               95     10               47
# 15      6               74      7               96     10               37
# 16      6               99     10               95     10               43
# 17      6               79      7               93     10               36
# 18      7               76      7               88      9               41
# 19      7               72      7               93     10               40
# 20      7               72      7               79      7               35
# 21      6               83      8               88      9               40
# 22      8               95     10               94     10               40
# 23      0               60      6               78      7               28
# 24      6               98     10               94     10               33
# 25      6               85      9               87      9               42
# 26      6               82      8               96     10               42
# 27      7               92     10               80      8               40
# 28      7               96     10               84      8               43
# 29      0               99     10               84      8               35
# 30      7               72      7               87      9               45
# 31      5               74      7               83      8               38
# 32      5               99     10               85      9               45
# 33      0               93     10               78      7               39
# 34      0               68      6               75      7               27
# 35      7               99     10               85      9               43
# 36      6               83      8               85      9               43
# 37      7               91     10               85      9               43
# 38      6               73      7               75      7               35
# 39      5               80      8               80      8               30
# 40      4               60      6               80      8               30
# 41      0               91     10               87      9               34
# 42      0               62      6               83      8               23
# 43      7               94     10               94     10               40
# 44      7               99     10               92     10               47
# 45      6               90     10               94     10               34
# 46      5               99     10               87      9               40
# 47      0               95     10               83      8               36
# 48      7               99     10               86      9               43
# 49      0               99     10               81      8               34
# 50      6               88      9               82      8               38
# 51      0               69      6               76      7               34
# 52      0               66      6               60      6               34
# 53      5               87      9               75      7               35
#
#     IT352  IT366_internals IT366
# 0       4                -   NaN
# 1       5               33   5.0
# 2       7               50   7.0
# 3       6                -   NaN
# 4       6                -   NaN
# 5       7               42   7.0
# 6       5                -   NaN
# 7       6               43   6.0
# 8       5               30   5.0
# 9       7                -   NaN
# 10      6                -   NaN
# 11      6               31   6.0
# 12      6               42   5.0
# 13      7               42   5.0
# 14      8               43   6.0
# 15      6                -   NaN
# 16      7               43   7.0
# 17      6                -   NaN
# 18      6               43   7.0
# 19      6                -   NaN
# 20      6                -   NaN
# 21      6               37   6.0
# 22      6                -   NaN
# 23      4                -   NaN
# 24      6                -   NaN
# 25      7                -   NaN
# 26      7                -   NaN
# 27      6               36   5.0
# 28      6               48   6.0
# 29      5               36   5.0
# 30      7               44   7.0
# 31      6                -   NaN
# 32      7               36   5.0
# 33      6               37   5.0
# 34      4                -   NaN
# 35      6               49   8.0
# 36      6                -   NaN
# 37      6                -   NaN
# 38      6                -   NaN
# 39      5                -   NaN
# 40      6                -   NaN
# 41      7                -   NaN
# 42      5                -   NaN
# 43      7                -   NaN
# 44      7               49   7.0
# 45      5                -   NaN
# 46      6               44   5.0
# 47      6                -   NaN
# 48      7                -   NaN
# 49      6               43   7.0
# 50      6               35   5.0
# 51      6                -   NaN
# 52      5               26   0.0
# 53      6                -   NaN
#
# [54 rows x 21 columns]

# %%
result = result.drop(["HS300_internals", "CS304_internals", "IT304_internals","IT306_internals","IT364_internals","IT302_internals","IT332_internals","IT334_internals","IT352_internals","IT366_internals"], axis=1)

# %%
#result = result.drop(["HS300", "CS304", "IT304","IT306","IT364","IT302","IT332","IT334","IT352","IT366"], axis=1)

# %%
result.to_csv (r's123.csv', index = False, header=True)

# %%
result.dropna(inplace=True)

# %%
result.to_csv (r's6_internal.csv', index = False, header=True)
