# %%
import pandas as pd
result=pd.read_csv('Downloads/s2.csv')
#result.head()
#result.info()

# %%
def nominalToNumber(dataframe,column,mapping):
    dataframe[column] = dataframe[column].map(mapping)
    return dataframe

def encodeData(studentData):
    registerno={
'TRV16IT001':1,
'TRV16IT002':2,
'TRV16IT003':3,
'TRV16IT005':5,
'TRV16IT006':6,
'TRV16IT007':7,
'TRV16IT008':8,
'TRV16IT009':9,
'TRV16IT010':10,
'TRV16IT011':11,
'TRV16IT012':12,
'TRV16IT013':13,
'TRV16IT015':15,
'TRV16IT016':16,
'TRV16IT017':17,
'TRV16IT018':18,
'TRV16IT019':19,
'TRV16IT020':20,
'TRV16IT021':21,
'TRV16IT022':22,
'TRV16IT023':23,
'TRV16IT024':24,
'TRV16IT025':25,
'TRV16IT026':26,
'TRV16IT028':28,
'TRV16IT030':30,
'TRV16IT031':31,
'TRV16IT032':32,
'TRV16IT033':33,
'TRV16IT034':34,
'TRV16IT035':35,
'TRV16IT036':36,
'TRV16IT037':37,
'TRV16IT038':38,
'TRV16IT039':39,
'TRV16IT040':40,
'TRV16IT041':41,
'TRV16IT042':42,
'TRV16IT043':43,
'TRV16IT044':44,
'TRV16IT045':45,
'TRV16IT046':46,
'TRV16IT048':48,
'TRV16IT049':49,
'TRV16IT050':50,
'TRV16IT051':51,
'TRV16IT052':52,
'TRV16IT053':53,
'TRV16IT054':54,
'TRV16IT055':55,
'TRV16IT056':56,
'TRV16IT057':57,
'TRV16IT058':58,
'TRV16IT059':59,
'TRV16IT060':60,
'TRV16IT061':61,
'TRV16IT062':62
}
    
    studentData = nominalToNumber(studentData,'NO.',registerno)
    
    gradeMapping = {'O':10,'A+':9,'A':8,'B+':7,'B':6,'C':5,'P':4,'F':0,'FE':0,'I':0}
    studentData = nominalToNumber(studentData,'CY100',gradeMapping)
    studentData = nominalToNumber(studentData,'BE100',gradeMapping)
    studentData = nominalToNumber(studentData,'EE100',gradeMapping)
    studentData = nominalToNumber(studentData,'CY110',gradeMapping)
    studentData = nominalToNumber(studentData,'EE110',gradeMapping)
    studentData = nominalToNumber(studentData,'MA102',gradeMapping)
    studentData = nominalToNumber(studentData,'BE102',gradeMapping)
    studentData = nominalToNumber(studentData,'CS100',gradeMapping)
    studentData = nominalToNumber(studentData,'CS120',gradeMapping)

    return studentData

# %%
result.columns
# Out:
# Index(['NO.', 'CY100_internals', 'CY100', 'BE100_internals', 'BE100',
#        'EE100_internals', 'EE100', 'CY110_internals', 'CY110',
#        'EE110_internals', 'EE110', 'MA102_internals', 'MA102',
#        'BE102_internals', 'BE102', 'CS100_internals', 'CS100',
#        'CS120_internals', 'CS120'],
#       dtype='object')

# %%
encodeData(result)
# Out:
#     NO. CY100_internals  CY100  BE100_internals  BE100  EE100_internals  \
# 0     1              24      5               28      0               23
# 1     2              33      6               35      5               30
# 2     3              47      9               46      5               48
# 3     5              47      7               45      5               46
# 4     6              35      7               37      6               41
# 5     7              43      7               39      7               36
# 6     8              31      6               34      5               27
# 7     9              40      6               29      0               34
# 8    10              27      5               39      5               23
# 9    11              45      7               42      7               44
# 10   12              30      5               31      0               24
# 11   13              41      7               38      5               35
# 12   15              41      6               46      5               42
# 13   16              46      7               47      7               46
# 14   17              36      0               47      5               39
# 15   18              23      0               27      0               23
# 16   19              41      6               40      6               33
# 17   20              42      6               43      5               42
# 18   21              33      0               25      0               40
# 19   22              41      6               38      6               36
# 20   23              38      7               32      6               37
# 21   24              39      0               41      0               26
# 22   25              29      5               37      5               27
# 23   26              40      6               42      7               41
# 24   28              24      5               23      0               23
# 25   30              33      5               40      7               39
# 26   31              23      0               38      5               23
# 27   32              23      0               26      0               23
# 28   33              35      7               44      6               30
# 29   34              33      6               31      0               23
# 30   35              40      6               35      0               34
# 31   36              37      6               34      0               29
# 32   37              46      9               44      7               35
# 33   38              31      5               33      5               34
# 34   39              41      6               47      7               35
# 35   40              37      6               39      5               30
# 36   41              30      0               32      5               23
# 37   42              42      7               45      6               36
# 38   43              40      6               49      7               38
# 39   44              42      6               46      6               45
# 40   45              34      5               32      5               29
# 41   46               -      0               32      0               23
# 42   48              30      5               33      5               23
# 43   49              32      0               42      6               30
# 44   50              28      5               29      0               23
# 45   51              25      0               30      5               23
# 46   52              42      6               48      6               45
# 47   53              42      6               44      7               43
# 48   54              40      7               34      5               41
# 49   55              36      0               34      5               39
# 50   56              46      7               46      6               42
# 51   57              42      6               33      6               48
# 52   58              34      5               42      6               35
# 53   59              27      0               34      0               23
# 54   60              32      0               35      0               28
# 55   61              23      4               25      0               23
# 56   62              28      5               33      0               26
#
#     EE100  CY110_internals  CY110  EE110_internals  EE110 MA102_internals  \
# 0     5.0               92     10               88      9              23
# 1     5.0              100     10               89      9              37
# 2     9.0               99     10               89      9              46
# 3    10.0               99     10               95     10              42
# 4     9.0               98     10               90     10              35
# 5     8.0               98     10               80      8              38
# 6     5.0               97     10               92     10              28
# 7     6.0               99     10               86      9              31
# 8     4.0              100     10               91     10              24
# 9     9.0               98     10               94     10              46
# 10    0.0               99     10               89      9              23
# 11    6.0               96     10               94     10              29
# 12    8.0               98     10               95     10              42
# 13    8.0               96     10               96     10              43
# 14    6.0               98     10               93     10              36
# 15    0.0               93     10               79      7              23
# 16    7.0              100     10               89      9              35
# 17    7.0               97     10               94     10              30
# 18    8.0               95     10               93     10              35
# 19    7.0              100     10               82      8              31
# 20    7.0               99     10               83      8              39
# 21    5.0               99     10               93     10              23
# 22    5.0               96     10               83      8              24
# 23    7.0              100     10               91     10              39
# 24    0.0               95     10               78      7              23
# 25    8.0               95     10               93     10              31
# 26    0.0              100     10               95     10              28
# 27    0.0               96     10               74      7               -
# 28    6.0               98     10               87      9              29
# 29    NaN               96     10               84      8              23
# 30    6.0               99     10               89      9              36
# 31    5.0              100     10               91     10              23
# 32    8.0              100     10               96     10              38
# 33    6.0               94     10               88      9              25
# 34    7.0              100     10               92     10              32
# 35    5.0               97     10               89      9              29
# 36    5.0               97     10               90     10              24
# 37    7.0               99     10               94     10              37
# 38    8.0               98     10               91     10              42
# 39    8.0               96     10               94     10              42
# 40    5.0               95     10               90     10              33
# 41    0.0              100     10               92     10              23
# 42    5.0               94     10               91     10              23
# 43    6.0               96     10               90     10              27
# 44    0.0               94     10               85      9              23
# 45    4.0               96     10               87      9              23
# 46    9.0               98     10               94     10              35
# 47    8.0               99     10               91     10              30
# 48    8.0               99     10               93     10              40
# 49    6.0               98     10               94     10              37
# 50    9.0               98     10               93     10              36
# 51   10.0              100     10               96     10              40
# 52    7.0               94     10               91     10              34
# 53    0.0               96     10               69      6              23
# 54    5.0              100     10               96     10              23
# 55    0.0               94     10               78      7              23
# 56    0.0               94     10               94     10              23
#
#     MA102  BE102_internals  BE102  CS100_internals  CS100  CS120_internals  \
# 0     6.0               80      0               27      0               75
# 1     8.0               92      6               37      7               78
# 2    10.0               97      7               41      7               92
# 3     8.0               99     10               34      6               81
# 4     8.0               89      7               36      6               92
# 5    10.0               91      7               46     10               98
# 6     0.0               91      6               30      0               63
# 7     7.0               84      7               34      6               72
# 8     5.0               91      8               26      0               56
# 9     9.0               94      8               40      7               96
# 10    5.0               78      0               30      0               72
# 11    7.0               92      6               37      7               81
# 12   10.0               90      6               39      8               84
# 13   10.0               94      7               44      8               96
# 14    9.0               95      7               40     10               94
# 15    0.0               87      6               25      0               75
# 16    8.0               97      9               33      5               81
# 17    7.0               91      0               40      6               87
# 18    7.0               84      7               30      0               72
# 19    8.0               91      8               42      7               92
# 20    9.0               89      8               44      7              100
# 21    NaN               90      7               30      0               84
# 22    6.0               89      7               30      5               92
# 23   10.0               92      8               45      7               87
# 24    0.0               77      7               25      4               72
# 25    7.0               88      8               33      6               92
# 26    5.0               91      9               32      0               92
# 27    0.0               90      6               25      0               54
# 28    6.0               92      7               42      7               92
# 29    5.0               83      0               31      6               87
# 30    9.0               92      9               30      5               92
# 31    6.0               85      7               30      0               72
# 32    7.0               96      9               46      7               98
# 33    6.0               83      7               41      7               92
# 34    8.0               88      9               45      6               98
# 35    5.0               89      8               32      0               72
# 36    6.0               86      8               32      0               66
# 37    6.0               95     10               44      6               94
# 38    7.0               89      9               35      5               92
# 39    8.0               89      8               39      6               98
# 40    6.0               87      9               41      6               96
# 41    5.0               76      7               25      0               92
# 42    5.0               85      8               25      0               51
# 43    5.0               84      8               41      7               92
# 44    0.0               87      8               26      0               51
# 45    5.0               74      6               26      0               63
# 46    9.0               87      9               38      7               78
# 47    8.0               81      8               41      7              100
# 48    7.0               90      8               37      7               94
# 49    5.0               82      7               37      6               98
# 50    9.0               87      7               37      7               94
# 51    9.0               89      9               40      7               94
# 52    8.0               91      9               32      5               72
# 53    5.0               70      6               25      0               92
# 54    7.0               85      7               32      5               54
# 55    7.0               71      6               25      0               72
# 56    5.0               77      7               31      5               63
#
#     CS120
# 0       7
# 1       7
# 2      10
# 3       8
# 4      10
# 5      10
# 6       6
# 7       7
# 8       5
# 9      10
# 10      7
# 11      8
# 12      8
# 13     10
# 14     10
# 15      7
# 16      8
# 17      9
# 18      7
# 19     10
# 20     10
# 21      8
# 22     10
# 23      9
# 24      7
# 25     10
# 26     10
# 27      5
# 28     10
# 29      9
# 30     10
# 31      7
# 32     10
# 33     10
# 34     10
# 35      7
# 36      6
# 37     10
# 38     10
# 39     10
# 40     10
# 41     10
# 42      5
# 43     10
# 44      5
# 45      6
# 46      7
# 47     10
# 48     10
# 49     10
# 50     10
# 51     10
# 52      7
# 53     10
# 54      5
# 55      7
# 56      6

# %%
#result.info()

# %%
#result.head()

# %%
#result = result.drop(["CY100_internals", "BE100_internals", "EE100_internals","CY110_internals","EE110_internals","MA102_internals","BE102_internals","CS100_internals","CS120_internals"], axis=1)

# %%
result = result.drop(["CY100", "BE100", "EE100","CY110","EE110","MA102","BE102","CS100","CS120"], axis=1)

# %%
result.to_csv (r's123.csv', index = False, header=True)

# %%
result.dropna(inplace=True)

# %%
#result.head(20)

# %%
result.to_csv (r's2_internal.csv', index = False, header=True)

# %%
result.columns
# Out:
# Index(['NO.', 'CY100_internals', 'BE100_internals', 'EE100_internals',
#        'CY110_internals', 'EE110_internals', 'MA102_internals',
#        'BE102_internals', 'CS100_internals', 'CS120_internals'],
#       dtype='object')
